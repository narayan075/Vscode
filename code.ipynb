# %%
import pandas as pd

# %%
data  = pd.read_csv('ElectricCarData_Clean.csv')

# %%
data.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
data.value_counts()
# Out:
# Brand        Model                 AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  FastCharge_KmH  RapidCharge  PowerTrain  PlugType    BodyStyle  Segment  Seats  PriceEuro
# Aiways       U5                    9.0       150           335       188              350             Yes          FWD         Type 2 CCS  SUV        C        5      36057        1
# Audi         Q4 Sportback e-tron   6.3       180           410       188              550             Yes          AWD         Type 2 CCS  SUV        D        5      57500        1
#              Q4 e-tron             6.3       180           400       193              540             Yes          AWD         Type 2 CCS  SUV        D        5      55000        1
#              e-tron 50 quattro     6.8       190           280       231              450             Yes          AWD         Type 2 CCS  SUV        E        5      67358        1
# ...

# %%
data.tail(2)
# Out:
#        Brand                            Model  AccelSec  TopSpeed_KmH  \
# 101  Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102   Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 101       375              232            450         Yes        AWD
# 102       400              238            480         Yes        AWD
#
#        PlugType  BodyStyle Segment  Seats  PriceEuro
# 101  Type 2 CCS  Hatchback       C      5      65000
# 102  Type 2 CCS        SUV       E      5      62000

# %%
len(data.columns)
# Out:
# 14

# %%
data.shape
# Out:
# (103, 14)

# %%
data = data.rename(columns={'Brand':'Brands'})
data.head(2)
# Out:
#         Brands                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000

# %%
data.groupby('BodyStyle')['Brands'].count()
# Out:
# BodyStyle
# Cabrio        3
# Hatchback    32
# Liftback      5
# MPV           1
# Pickup        3
# SPV           3
# SUV          45
# Sedan        10
# Station       1
# Name: Brands, dtype: int64

# %%
data.groupby(['BodyStyle','Seats','RapidCharge'])['Brands'].count()
# Out:
# BodyStyle  Seats  RapidCharge
# Cabrio     2      No              1
#            4      Yes             2
# Hatchback  2      No              1
#            4      No              2
#                   Yes            11
#            5      Yes            18
# Liftback   5      Yes             5
# MPV        5      Yes             1
# Pickup     6      Yes             3
# SPV        5      No              1
#            7      Yes             2
# SUV        5      Yes            41
#            7      Yes             4
# Sedan      4      Yes             5
#            5      Yes             5
# Station    4      Yes             1
# Name: Brands, dtype: int64
